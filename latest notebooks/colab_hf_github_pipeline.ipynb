# %% [markdown]
# # Colab pipeline launcher (FABQ-RC)
# This is a copy of the Colab pipeline that mounts Drive, saves tensors/checkpoints, uploads to Hugging Face, and prepares GitHub commits. Open and run in Colab. See `../sub1quant/notebook/colab_hf_github_pipeline.ipynb` for the canonical copy.

# %%
print('Open the canonical pipeline notebook in sub1quant/notebook/colab_hf_github_pipeline.ipynb or copy its cells here.')
